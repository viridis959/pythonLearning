# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
k = 1000
a = 100 * k
b = 150 * k
c = 230 * k
d = 80 * k

# %%
L1 = [a, a + b, a + b + c, a + b + c + d]
L2 = [1, 2, 3, 4]
L3 = [a, b, c, d]

# %% [markdown]
# # 累積消費額折線圖

# %%
plot(L2, L1)

# %% [markdown]
# # 各器材所佔比例圓餅圖

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(L3, labels = L3, autopct = "%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1762c7eafc8>,
# ...
#  [Text(0.9313966113234438, 0.5852352966245338, '100000'),
#   Text(-0.42095177560159874, 1.0162674857624154, '150000'),
#   Text(-0.6365384137986222, -0.8971169643690471, '230000'),
#   Text(0.9910657898026469, -0.4772720401226704, '80000')],
#  [Text(0.5080345152673329, 0.3192192527042911, '17.9%'),
#   Text(-0.22961005941905382, 0.5543277195067721, '26.8%'),
#   Text(-0.34720277116288484, -0.4893365260194802, '41.1%'),
#   Text(0.5405813398923528, -0.2603302037032747, '14.3%')])
