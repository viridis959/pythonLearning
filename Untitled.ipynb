# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi / 2)
# Out:
# 1.0

# %%
plot([-2, 10, 3, 13, 5])

# %%
randn(10)
# Out:
# array([-1.45807653,  0.11897662, -0.57878605,  2.13366557,  0.9369027 ,
#        -1.48520134,  0.03774879, -1.31181253, -0.64279351,  0.06907555])

# %%
plot(randn(100))

# %% [markdown]
# 哈囉

# %% [markdown]
# # 我是大標題
# ## 我是小標題

# %% [markdown]
# ## 連結
#
# [政大 MOOC 網](http://google.com)

# %%
L = [3, 9, 10, 2, -3, 5]

# %%
plot(L)

# %%
plot(L)

# %%
print("Hello, world.")
# Out:
# Hello, world.
