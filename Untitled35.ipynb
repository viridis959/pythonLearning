# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


df = pd.read_csv('KRfin01.csv')
df2 = pd.read_csv('KRfin02.csv')
df = df.append(df2, ignore_index=True)

# %%
df = df.drop(columns = "top_lane_kill_rate")

# %%
df = df.drop(columns = "top_damage")

# %%
df = df.drop(columns = "mid_lane_kill_rate")

# %%
df = df.drop(columns = "mid_damage")

# %%
df = df.drop(columns = "jg_damage")

# %%
df = df.drop(columns = "adc_lane_kill_rate")

# %%
df = df.drop(columns = "adc_damage")

# %%
df = df.drop(columns = "sup_lane_kill_rate")

# %%
df = df.drop(columns = df.columns[0])

# %%
df.to_csv("KRfin.csv", encoding="utf-8")

# %%
pd.read_csv('KRfin01.csv')
# Out:
#       Unnamed: 0  top_win_rate  top_lane_kill_rate   top_kda  \
# 0              0        0.4810              0.4917  0.484848
# 1              1        0.5449              0.5590  0.521028
# 2              2        0.3922              0.3993  0.470732
# 3              3        0.4802              0.4227  0.439227
# 4              4        0.4487              0.4856  0.481108
# ...          ...           ...                 ...       ...
# 9229        9229        0.4578              0.3895  0.412027
# 9230        9230        0.4898              0.5156  0.444724
# 9231        9231        0.4761              0.3738  0.436754
# 9232        9232        0.4572              0.4655  0.450839
# 9233        9233        0.5016              0.5130  0.519380
#
#       top_kill_participate  top_damage  jg_win_rate    jg_kda  \
# 0                 0.515976    0.561628       0.5017  0.465600
# 1                 0.489691    0.518154       0.5069  0.485660
# ...
