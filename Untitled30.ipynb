# %%
M = [x[:] for x in [[False]*(22+1)]*(5+1)]

# %%
([[False for i in range(22 + 1)]  
            for i in range(5 + 1)])
# Out:
# [[False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False]]

# %%
def is_valid_subset_sum(s:list, T:int)->bool:
    subset = [x[:] for x in [[False]*(T+1)]*(len(s)+1)]
    n = len(s)  
    for i in range(n + 1): 
        subset[i][0] = True
    # If sum is not 0 and set is empty,  
    # then answer is false  
    for i in range(1, sum + 1): 
         subset[0][i]= False
              
    # Fill the subset table in botton up manner 
    for i in range(1, n + 1): 
        for j in range(1, sum + 1): 
            if j<set[i-1]: 
                subset[i][j] = subset[i-1][j] 
            if j>= set[i-1]: 
                subset[i][j] = (subset[i-1][j] or 
                                subset[i - 1][j-set[i-1]]) 
      
    # uncomment this code to print table  
    # for i in range(n + 1): 
    # for j in range(sum + 1): 
    # print (subset[i][j], end =" ") 
    # print() 
    return subset[n][sum] 
print(is_valid_subset_sum([1,9,2,10,5],22))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-29e487221bc4> in <module>
#      24     # print()
#      25     return subset[n][sum]
# ---> 26 print(is_valid_subset_sum([1,9,2,10,5],22))
#
# <ipython-input-7-29e487221bc4> in is_valid_subset_sum(s, T)
#       6     # If sum is not 0 and set is empty,
#       7     # then answer is false
# ----> 8     for i in range(1, sum + 1):
#       9          subset[0][i]= False
#      10
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'int'
