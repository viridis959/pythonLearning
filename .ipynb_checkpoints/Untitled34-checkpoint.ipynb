# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


df = pd.read_csv('KRfin01.csv')
df2 = pd.read_csv('KRfin02.csv')
df = df.append(df2, ignore_index=True)

#lets create train, validation, test sets
p=0.9
kiri=int(p*df.shape[0])
train_X,val_X,test_X=np.array(df.iloc[:kiri,1:-1]),np.array(df.iloc[kiri::2,1:-1]),np.array(df.iloc[kiri+1::2,1:-1])
train_Y,val_Y,test_Y=np.array(df.iloc[:kiri,-1]),np.array(df.iloc[kiri::2,-1]),np.array(df.iloc[kiri+1::2,-1])

# %%
from collections import Counter
train_Y_count=Counter(train_Y)
val_Y_count=Counter(val_Y)
test_Y_count=Counter(test_Y)

#Print Statistics
print("In train set: {} negative and {} positive".format(train_Y_count[0],train_Y_count[1]))
print("In val set: {} negative and {} positive".format(val_Y_count[0],val_Y_count[1]))
print("In test set: {} negative and {} positive".format(test_Y_count[0],test_Y_count[1]))
print("Train Set, Positive/Negative: {} %".format(train_Y_count[1]/train_Y_count[0]*100))
print("Val Set, Positive/Negative: {} %".format(val_Y_count[1]/val_Y_count[0]*100))
print("Test Set, Positive/Negative: {} %".format(test_Y_count[1]/test_Y_count[0]*100))
# Out:
# In train set: 8871 negative and 9075 positive
# In val set: 486 negative and 512 positive
# In test set: 506 negative and 491 positive
# Train Set, Positive/Negative: 102.29962800135273 %
# Val Set, Positive/Negative: 105.34979423868313 %
# Test Set, Positive/Negative: 97.03557312252964 %

# %%
train_data=TensorDataset(torch.from_numpy(train_X),torch.from_numpy(train_Y))
val_data=TensorDataset(torch.from_numpy(val_X),torch.from_numpy(val_Y))
test_data=TensorDataset(torch.from_numpy(test_X),torch.from_numpy(test_Y))

# %%
#find out the number positive and negative examples in the training set
num_classes=[train_Y_count[0],train_Y_count[1]]
#find the respective weights (mind that weights need to be a torch tensor)
weights=1./torch.tensor(num_classes,dtype=float)
#create a torch tensor associating the train_Y and the weights. Sample Weights is a torch tensor
sample_weights=weights[train_Y]
sampler=torch.utils.data.WeightedRandomSampler(weights=sample_weights,num_samples=len(sample_weights),replacement=True)

# %%
batch_size=50001
train_loader=DataLoader(train_data,sampler=sampler,batch_size=batch_size)
val_loader=DataLoader(val_data,shuffle=True,batch_size=batch_size)
test_loader=DataLoader(test_data,shuffle=False,batch_size=batch_size)

# %%
train_iter=iter(val_loader)
inputs,outputs=train_iter.next()
print(inputs)
# Out:
# tensor([[0.4839, 0.3238, 0.4038,  ..., 0.4410, 0.5104, 0.4741],
#         [0.5382, 0.5243, 0.5725,  ..., 0.5093, 0.4797, 0.5255],
#         [0.5251, 0.4062, 0.5464,  ..., 0.4696, 0.4733, 0.4854],
#         ...,
#         [0.4477, 0.4528, 0.5268,  ..., 0.5611, 0.4911, 0.4891],
#         [0.4943, 0.3442, 0.4233,  ..., 0.5317, 0.4204, 0.4989],
#         [0.5329, 0.7861, 0.4878,  ..., 0.4516, 0.4303, 0.4404]],
#        dtype=torch.float64)

# %%
print(inputs.size())
# Out:
# torch.Size([998, 23])

# %%
#loader wrapping
loaders={'train':train_loader, 'valid':val_loader}

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.fc1=nn.Linear(23,128)
        self.fc2=nn.Linear(128,15,bias=False)
        self.norm2=nn.BatchNorm1d(15)
        self.fc3=nn.Linear(15,10,bias=False)
        self.norm3=nn.BatchNorm1d(10)
        self.fc4=nn.Linear(10,5,bias=False)
        self.norm4=nn.BatchNorm1d(5)
        self.fc5=nn.Linear(5,1)
         
        
    def forward(self,x):
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=F.relu(self.fc3(x))
        x=F.relu(self.norm4(self.fc4(x)))
        x=torch.sigmoid(self.fc5(x))        
        return x

# %%
model = Net()
criterion=nn.BCEWithLogitsLoss()

# %%
optimizer=torch.optim.SGD(model.parameters(),lr=0.001,momentum=0.9)
scheduler=torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,mode="min",factor=0.75,patience=50,min_lr=1e-5)

# %%
def train(n_epochs,loaders,model,optimizer,criterion,scheduler):
    #Trains the neural network passed in "model", for a number of
    #epochs equal to n_epochs, on the loaders contained in the 
    #dictionary "loaders", using the optimizer in "optimizer", 
    #with the loss function defined in "criterion" and, if necessary
    #decreases the learning rate in accordance to the rules contained 
    #in "scheduler"
    valid_loss_min=np.Inf
    list_train_loss=[]
    list_valid_loss=[]
    for epoch in range(1,n_epochs+1):
        train_loss=0.0
        valid_loss=0.0
        model.train()
        for batch_idx,(data,target) in enumerate(loaders["train"]):
            optimizer.zero_grad()
            output=model(data.float())
            loss=criterion(output.squeeze(),target.float())
            loss.backward()
            optimizer.step()
            train_loss=train_loss+1/(batch_idx+1)*(loss.item()-train_loss)
        list_train_loss.append(train_loss)
        print("At {} epoch, Training Loss: {} ".format(epoch,train_loss))
        model.eval()
        for batch_idx,(data,target) in enumerate(loaders["valid"]):
            output=model(data.float())
            loss=criterion(output.squeeze(),target.float())
            valid_loss=valid_loss+1/(batch_idx+1)*(loss.item()-valid_loss)
        scheduler.step(valid_loss)
        list_valid_loss.append(valid_loss)
        print("At {} epoch, Validation Loss: {} ".format(epoch,valid_loss))
        #Save the model
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(),'ccFraud.pt')
            print("Minimum validation loss detected, saving model......................................................................................")
            valid_loss_min=valid_loss
    
    return model, list_train_loss, list_valid_loss

# %%
n_epoch=10000
model,train_loss,valid_loss=train(n_epoch,loaders,model,optimizer,criterion,scheduler)
# Out:
# At 1 epoch, Training Loss: 0.7171865701675415
# At 1 epoch, Validation Loss: 0.7095901966094971
# Minimum validation loss detected, saving model......................................................................................
# At 2 epoch, Training Loss: 0.7122880816459656
# At 2 epoch, Validation Loss: 0.7095887660980225
# Minimum validation loss detected, saving model......................................................................................
# At 3 epoch, Training Loss: 0.7154885530471802
# At 3 epoch, Validation Loss: 0.7095871567726135
# Minimum validation loss detected, saving model......................................................................................
# At 4 epoch, Training Loss: 0.7176935076713562
# At 4 epoch, Validation Loss: 0.7095851302146912
# Minimum validation loss detected, saving model......................................................................................
# At 5 epoch, Training Loss: 0.7149812579154968
# At 5 epoch, Validation Loss: 0.7095826864242554
# Minimum validation loss detected, saving model......................................................................................
# At 6 epoch, Training Loss: 0.7171754240989685
# At 6 epoch, Validation Loss: 0.7095801830291748
# Minimum validation loss detected, saving model......................................................................................
# At 7 epoch, Training Loss: 0.7142167091369629
# At 7 epoch, Validation Loss: 0.7095772624015808
# Minimum validation loss detected, saving model......................................................................................
# At 8 epoch, Training Loss: 0.71360182762146
# At 8 epoch, Validation Loss: 0.7095741033554077
# Minimum validation loss detected, saving model......................................................................................
# At 9 epoch, Training Loss: 0.7158221006393433
# At 9 epoch, Validation Loss: 0.7095707654953003
# Minimum validation loss detected, saving model......................................................................................
# At 10 epoch, Training Loss: 0.7133288383483887
# At 10 epoch, Validation Loss: 0.7095673084259033
# Minimum validation loss detected, saving model......................................................................................
# At 11 epoch, Training Loss: 0.7131949067115784
# At 11 epoch, Validation Loss: 0.7095638513565063
# Minimum validation loss detected, saving model......................................................................................
# At 12 epoch, Training Loss: 0.7164733409881592
# At 12 epoch, Validation Loss: 0.7095600366592407
# Minimum validation loss detected, saving model......................................................................................
# At 13 epoch, Training Loss: 0.7150693535804749
# At 13 epoch, Validation Loss: 0.7095559239387512
# Minimum validation loss detected, saving model......................................................................................
# At 14 epoch, Training Loss: 0.7181041240692139
# At 14 epoch, Validation Loss: 0.7095519304275513
# Minimum validation loss detected, saving model......................................................................................
# At 15 epoch, Training Loss: 0.715240478515625
# At 15 epoch, Validation Loss: 0.7095473408699036
# Minimum validation loss detected, saving model......................................................................................
# At 16 epoch, Training Loss: 0.7193349003791809
# At 16 epoch, Validation Loss: 0.7095425128936768
# Minimum validation loss detected, saving model......................................................................................
# At 17 epoch, Training Loss: 0.7124704122543335
# At 17 epoch, Validation Loss: 0.7095373868942261
# Minimum validation loss detected, saving model......................................................................................
# At 18 epoch, Training Loss: 0.7153649926185608
# At 18 epoch, Validation Loss: 0.7095319032669067
# Minimum validation loss detected, saving model......................................................................................
# At 19 epoch, Training Loss: 0.7163112163543701
# At 19 epoch, Validation Loss: 0.709526002407074
# Minimum validation loss detected, saving model......................................................................................
# At 20 epoch, Training Loss: 0.714083731174469
# At 20 epoch, Validation Loss: 0.7095202803611755
# Minimum validation loss detected, saving model......................................................................................
# At 21 epoch, Training Loss: 0.7158223986625671
# At 21 epoch, Validation Loss: 0.709514319896698
# Minimum validation loss detected, saving model......................................................................................
# At 22 epoch, Training Loss: 0.7141013145446777
# At 22 epoch, Validation Loss: 0.7095083594322205
# Minimum validation loss detected, saving model......................................................................................
# At 23 epoch, Training Loss: 0.7153106927871704
# At 23 epoch, Validation Loss: 0.7095023393630981
# Minimum validation loss detected, saving model......................................................................................
# At 24 epoch, Training Loss: 0.7157881855964661
# At 24 epoch, Validation Loss: 0.709496021270752
# Minimum validation loss detected, saving model......................................................................................
# At 25 epoch, Training Loss: 0.7135289907455444
# At 25 epoch, Validation Loss: 0.7094897627830505
# Minimum validation loss detected, saving model......................................................................................
# At 26 epoch, Training Loss: 0.716543436050415
# At 26 epoch, Validation Loss: 0.7094829678535461
# Minimum validation loss detected, saving model......................................................................................
# At 27 epoch, Training Loss: 0.718080997467041
# At 27 epoch, Validation Loss: 0.7094764709472656
# Minimum validation loss detected, saving model......................................................................................
# At 28 epoch, Training Loss: 0.7134685516357422
# At 28 epoch, Validation Loss: 0.7094696164131165
# Minimum validation loss detected, saving model......................................................................................
# At 29 epoch, Training Loss: 0.7139345407485962
# At 29 epoch, Validation Loss: 0.7094628214836121
# Minimum validation loss detected, saving model......................................................................................
# At 30 epoch, Training Loss: 0.7151424884796143
# At 30 epoch, Validation Loss: 0.7094559073448181
# Minimum validation loss detected, saving model......................................................................................
# At 31 epoch, Training Loss: 0.7139108777046204
# At 31 epoch, Validation Loss: 0.709449291229248
# Minimum validation loss detected, saving model......................................................................................
# At 32 epoch, Training Loss: 0.7146106958389282
# At 32 epoch, Validation Loss: 0.7094423174858093
# Minimum validation loss detected, saving model......................................................................................
# At 33 epoch, Training Loss: 0.7135554552078247
# At 33 epoch, Validation Loss: 0.7094354033470154
# Minimum validation loss detected, saving model......................................................................................
# At 34 epoch, Training Loss: 0.7149934768676758
# At 34 epoch, Validation Loss: 0.7094283699989319
# Minimum validation loss detected, saving model......................................................................................
# At 35 epoch, Training Loss: 0.7158578634262085
# At 35 epoch, Validation Loss: 0.7094209790229797
# Minimum validation loss detected, saving model......................................................................................
# At 36 epoch, Training Loss: 0.7139771580696106
# At 36 epoch, Validation Loss: 0.709414005279541
# Minimum validation loss detected, saving model......................................................................................
# At 37 epoch, Training Loss: 0.7142153978347778
# At 37 epoch, Validation Loss: 0.7094066143035889
# Minimum validation loss detected, saving model......................................................................................
# At 38 epoch, Training Loss: 0.7173911333084106
# At 38 epoch, Validation Loss: 0.7093995213508606
# Minimum validation loss detected, saving model......................................................................................
# At 39 epoch, Training Loss: 0.7146093249320984
# At 39 epoch, Validation Loss: 0.7093924880027771
# Minimum validation loss detected, saving model......................................................................................
# At 40 epoch, Training Loss: 0.715353786945343
# At 40 epoch, Validation Loss: 0.709385335445404
# Minimum validation loss detected, saving model......................................................................................
# At 41 epoch, Training Loss: 0.7140320539474487
# At 41 epoch, Validation Loss: 0.7093780636787415
# Minimum validation loss detected, saving model......................................................................................
# At 42 epoch, Training Loss: 0.7144767045974731
# At 42 epoch, Validation Loss: 0.7093707919120789
# Minimum validation loss detected, saving model......................................................................................
# At 43 epoch, Training Loss: 0.7164578437805176
# At 43 epoch, Validation Loss: 0.7093631029129028
# Minimum validation loss detected, saving model......................................................................................
# At 44 epoch, Training Loss: 0.7136633396148682
# At 44 epoch, Validation Loss: 0.7093554139137268
# Minimum validation loss detected, saving model......................................................................................
# At 45 epoch, Training Loss: 0.7147815823554993
# At 45 epoch, Validation Loss: 0.7093473672866821
# Minimum validation loss detected, saving model......................................................................................
# At 46 epoch, Training Loss: 0.7134098410606384
# At 46 epoch, Validation Loss: 0.7093397974967957
# Minimum validation loss detected, saving model......................................................................................
# At 47 epoch, Training Loss: 0.7139899730682373
# At 47 epoch, Validation Loss: 0.7093315720558167
# Minimum validation loss detected, saving model......................................................................................
# At 48 epoch, Training Loss: 0.7124419212341309
# At 48 epoch, Validation Loss: 0.7093239426612854
# Minimum validation loss detected, saving model......................................................................................
# At 49 epoch, Training Loss: 0.7176627516746521
# At 49 epoch, Validation Loss: 0.7093157768249512
# Minimum validation loss detected, saving model......................................................................................
# At 50 epoch, Training Loss: 0.7128931283950806
# At 50 epoch, Validation Loss: 0.7093079090118408
# Minimum validation loss detected, saving model......................................................................................
# At 51 epoch, Training Loss: 0.7138186097145081
# At 51 epoch, Validation Loss: 0.7092995643615723
# Minimum validation loss detected, saving model......................................................................................
# At 52 epoch, Training Loss: 0.7118842601776123
# At 52 epoch, Validation Loss: 0.7092911005020142
# Minimum validation loss detected, saving model......................................................................................
# At 53 epoch, Training Loss: 0.7142157554626465
# At 53 epoch, Validation Loss: 0.7092827558517456
# Minimum validation loss detected, saving model......................................................................................
# At 54 epoch, Training Loss: 0.7173348665237427
# At 54 epoch, Validation Loss: 0.7092737555503845
# Minimum validation loss detected, saving model......................................................................................
# At 55 epoch, Training Loss: 0.7132411003112793
# At 55 epoch, Validation Loss: 0.709265410900116
# Minimum validation loss detected, saving model......................................................................................
# At 56 epoch, Training Loss: 0.714900016784668
# At 56 epoch, Validation Loss: 0.7092567682266235
# Minimum validation loss detected, saving model......................................................................................
# At 57 epoch, Training Loss: 0.7139785289764404
# At 57 epoch, Validation Loss: 0.7092478275299072
# Minimum validation loss detected, saving model......................................................................................
# At 58 epoch, Training Loss: 0.7122371792793274
# At 58 epoch, Validation Loss: 0.7092387080192566
# Minimum validation loss detected, saving model......................................................................................
# At 59 epoch, Training Loss: 0.713451623916626
# At 59 epoch, Validation Loss: 0.7092294692993164
# Minimum validation loss detected, saving model......................................................................................
# At 60 epoch, Training Loss: 0.7124391794204712
# At 60 epoch, Validation Loss: 0.7092201113700867
# Minimum validation loss detected, saving model......................................................................................
# At 61 epoch, Training Loss: 0.7145524024963379
# At 61 epoch, Validation Loss: 0.7092108130455017
# Minimum validation loss detected, saving model......................................................................................
# At 62 epoch, Training Loss: 0.7141067981719971
# At 62 epoch, Validation Loss: 0.7092016339302063
# Minimum validation loss detected, saving model......................................................................................
# At 63 epoch, Training Loss: 0.7118260860443115
# At 63 epoch, Validation Loss: 0.7091916799545288
# Minimum validation loss detected, saving model......................................................................................
# At 64 epoch, Training Loss: 0.7145175933837891
# At 64 epoch, Validation Loss: 0.7091819643974304
# Minimum validation loss detected, saving model......................................................................................
# At 65 epoch, Training Loss: 0.7156485319137573
# At 65 epoch, Validation Loss: 0.709172248840332
# Minimum validation loss detected, saving model......................................................................................
# At 66 epoch, Training Loss: 0.7137829065322876
# At 66 epoch, Validation Loss: 0.7091628909111023
# Minimum validation loss detected, saving model......................................................................................
# At 67 epoch, Training Loss: 0.7130985260009766
# At 67 epoch, Validation Loss: 0.7091532945632935
# Minimum validation loss detected, saving model......................................................................................
# At 68 epoch, Training Loss: 0.7123714089393616
# At 68 epoch, Validation Loss: 0.7091431021690369
# Minimum validation loss detected, saving model......................................................................................
# At 69 epoch, Training Loss: 0.7152688503265381
# At 69 epoch, Validation Loss: 0.7091332077980042
# Minimum validation loss detected, saving model......................................................................................
# At 70 epoch, Training Loss: 0.7140613198280334
# At 70 epoch, Validation Loss: 0.7091225981712341
# Minimum validation loss detected, saving model......................................................................................
# At 71 epoch, Training Loss: 0.715221107006073
# At 71 epoch, Validation Loss: 0.709109902381897
# Minimum validation loss detected, saving model......................................................................................
# At 72 epoch, Training Loss: 0.7097294330596924
# At 72 epoch, Validation Loss: 0.7090973854064941
# Minimum validation loss detected, saving model......................................................................................
# At 73 epoch, Training Loss: 0.7157356142997742
# At 73 epoch, Validation Loss: 0.7090849876403809
# Minimum validation loss detected, saving model......................................................................................
# At 74 epoch, Training Loss: 0.7141815423965454
# At 74 epoch, Validation Loss: 0.7090716361999512
# Minimum validation loss detected, saving model......................................................................................
# At 75 epoch, Training Loss: 0.716707170009613
# At 75 epoch, Validation Loss: 0.7090595960617065
# Minimum validation loss detected, saving model......................................................................................
# At 76 epoch, Training Loss: 0.7134615182876587
# At 76 epoch, Validation Loss: 0.7090463042259216
# Minimum validation loss detected, saving model......................................................................................
# At 77 epoch, Training Loss: 0.7155309915542603
# At 77 epoch, Validation Loss: 0.7090334892272949
# Minimum validation loss detected, saving model......................................................................................
# At 78 epoch, Training Loss: 0.7145675420761108
# At 78 epoch, Validation Loss: 0.7090206146240234
# Minimum validation loss detected, saving model......................................................................................
# At 79 epoch, Training Loss: 0.7123907208442688
# At 79 epoch, Validation Loss: 0.7090067267417908
# Minimum validation loss detected, saving model......................................................................................
# At 80 epoch, Training Loss: 0.7155284285545349
# At 80 epoch, Validation Loss: 0.7089931964874268
# Minimum validation loss detected, saving model......................................................................................
# At 81 epoch, Training Loss: 0.7124224305152893
# At 81 epoch, Validation Loss: 0.7089779376983643
# Minimum validation loss detected, saving model......................................................................................
# At 82 epoch, Training Loss: 0.7157967686653137
# At 82 epoch, Validation Loss: 0.7089636325836182
# Minimum validation loss detected, saving model......................................................................................
# At 83 epoch, Training Loss: 0.7137803435325623
# At 83 epoch, Validation Loss: 0.7089487314224243
# Minimum validation loss detected, saving model......................................................................................
# At 84 epoch, Training Loss: 0.7163819074630737
# At 84 epoch, Validation Loss: 0.7089341878890991
# Minimum validation loss detected, saving model......................................................................................
# At 85 epoch, Training Loss: 0.7141225337982178
# At 85 epoch, Validation Loss: 0.7089177966117859
# Minimum validation loss detected, saving model......................................................................................
# At 86 epoch, Training Loss: 0.7125474214553833
# At 86 epoch, Validation Loss: 0.7089017033576965
# Minimum validation loss detected, saving model......................................................................................
# At 87 epoch, Training Loss: 0.7170782685279846
# At 87 epoch, Validation Loss: 0.7088855504989624
# Minimum validation loss detected, saving model......................................................................................
# At 88 epoch, Training Loss: 0.7130258083343506
# At 88 epoch, Validation Loss: 0.7088702321052551
# Minimum validation loss detected, saving model......................................................................................
# At 89 epoch, Training Loss: 0.7150266170501709
# At 89 epoch, Validation Loss: 0.7088562250137329
# Minimum validation loss detected, saving model......................................................................................
# At 90 epoch, Training Loss: 0.7160732746124268
# At 90 epoch, Validation Loss: 0.7088402509689331
# Minimum validation loss detected, saving model......................................................................................
# At 91 epoch, Training Loss: 0.7114377021789551
# At 91 epoch, Validation Loss: 0.7088261246681213
# Minimum validation loss detected, saving model......................................................................................
# At 92 epoch, Training Loss: 0.7134076356887817
# At 92 epoch, Validation Loss: 0.7088131904602051
# Minimum validation loss detected, saving model......................................................................................
# At 93 epoch, Training Loss: 0.7152925729751587
# At 93 epoch, Validation Loss: 0.7087950706481934
# Minimum validation loss detected, saving model......................................................................................
# At 94 epoch, Training Loss: 0.712331235408783
# At 94 epoch, Validation Loss: 0.7087793350219727
# Minimum validation loss detected, saving model......................................................................................
# At 95 epoch, Training Loss: 0.7136762142181396
# At 95 epoch, Validation Loss: 0.708763062953949
# Minimum validation loss detected, saving model......................................................................................
# At 96 epoch, Training Loss: 0.713206946849823
# At 96 epoch, Validation Loss: 0.7087499499320984
# Minimum validation loss detected, saving model......................................................................................
# At 97 epoch, Training Loss: 0.7151162028312683
# At 97 epoch, Validation Loss: 0.7087330222129822
# Minimum validation loss detected, saving model......................................................................................
# At 98 epoch, Training Loss: 0.7142632603645325
# At 98 epoch, Validation Loss: 0.708717405796051
# Minimum validation loss detected, saving model......................................................................................
# At 99 epoch, Training Loss: 0.7157783508300781
# At 99 epoch, Validation Loss: 0.7087067365646362
# Minimum validation loss detected, saving model......................................................................................
# At 100 epoch, Training Loss: 0.7133265733718872
# At 100 epoch, Validation Loss: 0.708694577217102
# Minimum validation loss detected, saving model......................................................................................
# At 101 epoch, Training Loss: 0.7127177119255066
# At 101 epoch, Validation Loss: 0.7086791396141052
# Minimum validation loss detected, saving model......................................................................................
# At 102 epoch, Training Loss: 0.7120218873023987
# At 102 epoch, Validation Loss: 0.7086620330810547
# Minimum validation loss detected, saving model......................................................................................
# At 103 epoch, Training Loss: 0.7129348516464233
# At 103 epoch, Validation Loss: 0.7086476683616638
# Minimum validation loss detected, saving model......................................................................................
# At 104 epoch, Training Loss: 0.7135976552963257
# At 104 epoch, Validation Loss: 0.7086316347122192
# Minimum validation loss detected, saving model......................................................................................
# At 105 epoch, Training Loss: 0.7124148607254028
# At 105 epoch, Validation Loss: 0.7086175084114075
# Minimum validation loss detected, saving model......................................................................................
# At 106 epoch, Training Loss: 0.7122634053230286
# At 106 epoch, Validation Loss: 0.7086032032966614
# Minimum validation loss detected, saving model......................................................................................
# At 107 epoch, Training Loss: 0.7133864760398865
# At 107 epoch, Validation Loss: 0.7085859775543213
# Minimum validation loss detected, saving model......................................................................................
# At 108 epoch, Training Loss: 0.7126283645629883
# At 108 epoch, Validation Loss: 0.7085680961608887
# Minimum validation loss detected, saving model......................................................................................
# At 109 epoch, Training Loss: 0.7172510623931885
# At 109 epoch, Validation Loss: 0.7085526585578918
# Minimum validation loss detected, saving model......................................................................................
# At 110 epoch, Training Loss: 0.7143585085868835
# At 110 epoch, Validation Loss: 0.7085373997688293
# Minimum validation loss detected, saving model......................................................................................
# At 111 epoch, Training Loss: 0.7129939198493958
# At 111 epoch, Validation Loss: 0.7085208296775818
# Minimum validation loss detected, saving model......................................................................................
# At 112 epoch, Training Loss: 0.7144388556480408
# At 112 epoch, Validation Loss: 0.7085041999816895
# Minimum validation loss detected, saving model......................................................................................
# At 113 epoch, Training Loss: 0.7114328145980835
# At 113 epoch, Validation Loss: 0.7084954977035522
# Minimum validation loss detected, saving model......................................................................................
# At 114 epoch, Training Loss: 0.7161533236503601
# At 114 epoch, Validation Loss: 0.7084832191467285
# Minimum validation loss detected, saving model......................................................................................
# At 115 epoch, Training Loss: 0.7145982384681702
# At 115 epoch, Validation Loss: 0.7084692120552063
# Minimum validation loss detected, saving model......................................................................................
# At 116 epoch, Training Loss: 0.7135719060897827
# At 116 epoch, Validation Loss: 0.7084575295448303
# Minimum validation loss detected, saving model......................................................................................
# At 117 epoch, Training Loss: 0.7145139575004578
# At 117 epoch, Validation Loss: 0.7084497809410095
# Minimum validation loss detected, saving model......................................................................................
# At 118 epoch, Training Loss: 0.713768720626831
# At 118 epoch, Validation Loss: 0.7084413170814514
# Minimum validation loss detected, saving model......................................................................................
# At 119 epoch, Training Loss: 0.7138264775276184
# At 119 epoch, Validation Loss: 0.7084272503852844
# Minimum validation loss detected, saving model......................................................................................
# At 120 epoch, Training Loss: 0.7128218412399292
# At 120 epoch, Validation Loss: 0.708420991897583
# Minimum validation loss detected, saving model......................................................................................
# At 121 epoch, Training Loss: 0.713432252407074
# At 121 epoch, Validation Loss: 0.7084153890609741
# Minimum validation loss detected, saving model......................................................................................
# At 122 epoch, Training Loss: 0.7141928672790527
# At 122 epoch, Validation Loss: 0.7084050178527832
# Minimum validation loss detected, saving model......................................................................................
# At 123 epoch, Training Loss: 0.7123101353645325
# At 123 epoch, Validation Loss: 0.7083932757377625
# Minimum validation loss detected, saving model......................................................................................
# At 124 epoch, Training Loss: 0.7143320441246033
# At 124 epoch, Validation Loss: 0.7083850502967834
# Minimum validation loss detected, saving model......................................................................................
# At 125 epoch, Training Loss: 0.7129591107368469
# At 125 epoch, Validation Loss: 0.7083763480186462
# Minimum validation loss detected, saving model......................................................................................
# At 126 epoch, Training Loss: 0.7130054831504822
# At 126 epoch, Validation Loss: 0.7083685994148254
# Minimum validation loss detected, saving model......................................................................................
# At 127 epoch, Training Loss: 0.7154140472412109
# At 127 epoch, Validation Loss: 0.708352267742157
# Minimum validation loss detected, saving model......................................................................................
# At 128 epoch, Training Loss: 0.7135130763053894
# At 128 epoch, Validation Loss: 0.7083396911621094
# Minimum validation loss detected, saving model......................................................................................
# At 129 epoch, Training Loss: 0.7151023745536804
# At 129 epoch, Validation Loss: 0.7083271741867065
# Minimum validation loss detected, saving model......................................................................................
# At 130 epoch, Training Loss: 0.7152089476585388
# At 130 epoch, Validation Loss: 0.708314836025238
# Minimum validation loss detected, saving model......................................................................................
# At 131 epoch, Training Loss: 0.7138339877128601
# At 131 epoch, Validation Loss: 0.70830899477005
# Minimum validation loss detected, saving model......................................................................................
# At 132 epoch, Training Loss: 0.7145293951034546
# At 132 epoch, Validation Loss: 0.7082983255386353
# Minimum validation loss detected, saving model......................................................................................
# At 133 epoch, Training Loss: 0.7154617309570312
# At 133 epoch, Validation Loss: 0.7082971334457397
# Minimum validation loss detected, saving model......................................................................................
# At 134 epoch, Training Loss: 0.7104174494743347
# At 134 epoch, Validation Loss: 0.7082916498184204
# Minimum validation loss detected, saving model......................................................................................
# At 135 epoch, Training Loss: 0.713396430015564
# At 135 epoch, Validation Loss: 0.7082902193069458
# Minimum validation loss detected, saving model......................................................................................
# At 136 epoch, Training Loss: 0.7124198079109192
# At 136 epoch, Validation Loss: 0.708289384841919
# Minimum validation loss detected, saving model......................................................................................
# At 137 epoch, Training Loss: 0.7135230302810669
# At 137 epoch, Validation Loss: 0.7082829475402832
# Minimum validation loss detected, saving model......................................................................................
# At 138 epoch, Training Loss: 0.7161412239074707
# At 138 epoch, Validation Loss: 0.7082796096801758
# Minimum validation loss detected, saving model......................................................................................
# At 139 epoch, Training Loss: 0.7134355306625366
# At 139 epoch, Validation Loss: 0.7082713842391968
# Minimum validation loss detected, saving model......................................................................................
# At 140 epoch, Training Loss: 0.7156906127929688
# At 140 epoch, Validation Loss: 0.7082632780075073
# Minimum validation loss detected, saving model......................................................................................
# At 141 epoch, Training Loss: 0.7146615386009216
# At 141 epoch, Validation Loss: 0.7082546353340149
# Minimum validation loss detected, saving model......................................................................................
# At 142 epoch, Training Loss: 0.7143929600715637
# At 142 epoch, Validation Loss: 0.7082491517066956
# Minimum validation loss detected, saving model......................................................................................
# At 143 epoch, Training Loss: 0.7150000929832458
# At 143 epoch, Validation Loss: 0.708239734172821
# Minimum validation loss detected, saving model......................................................................................
# At 144 epoch, Training Loss: 0.7125821709632874
# At 144 epoch, Validation Loss: 0.708230197429657
# Minimum validation loss detected, saving model......................................................................................
# At 145 epoch, Training Loss: 0.7107449173927307
# At 145 epoch, Validation Loss: 0.7082164883613586
# Minimum validation loss detected, saving model......................................................................................
# At 146 epoch, Training Loss: 0.7133185863494873
# At 146 epoch, Validation Loss: 0.7082035541534424
# Minimum validation loss detected, saving model......................................................................................
# At 147 epoch, Training Loss: 0.7149261236190796
# At 147 epoch, Validation Loss: 0.7081935405731201
# Minimum validation loss detected, saving model......................................................................................
# At 148 epoch, Training Loss: 0.7153943777084351
# At 148 epoch, Validation Loss: 0.7081865668296814
# Minimum validation loss detected, saving model......................................................................................
# At 149 epoch, Training Loss: 0.7133080363273621
# At 149 epoch, Validation Loss: 0.7081716656684875
# Minimum validation loss detected, saving model......................................................................................
# At 150 epoch, Training Loss: 0.7116836905479431
# At 150 epoch, Validation Loss: 0.7081579566001892
# Minimum validation loss detected, saving model......................................................................................
# At 151 epoch, Training Loss: 0.7160928845405579
# At 151 epoch, Validation Loss: 0.7081422209739685
# Minimum validation loss detected, saving model......................................................................................
# At 152 epoch, Training Loss: 0.7147850394248962
# At 152 epoch, Validation Loss: 0.7081237435340881
# Minimum validation loss detected, saving model......................................................................................
# At 153 epoch, Training Loss: 0.7107618451118469
# At 153 epoch, Validation Loss: 0.7081095576286316
# Minimum validation loss detected, saving model......................................................................................
# At 154 epoch, Training Loss: 0.7118626236915588
# At 154 epoch, Validation Loss: 0.7080925107002258
# Minimum validation loss detected, saving model......................................................................................
# At 155 epoch, Training Loss: 0.7149308323860168
# At 155 epoch, Validation Loss: 0.7080770134925842
# Minimum validation loss detected, saving model......................................................................................
# At 156 epoch, Training Loss: 0.7158485054969788
# At 156 epoch, Validation Loss: 0.7080636620521545
# Minimum validation loss detected, saving model......................................................................................
# At 157 epoch, Training Loss: 0.711740255355835
# At 157 epoch, Validation Loss: 0.7080539464950562
# Minimum validation loss detected, saving model......................................................................................
# At 158 epoch, Training Loss: 0.7109594345092773
# At 158 epoch, Validation Loss: 0.7080405354499817
# Minimum validation loss detected, saving model......................................................................................
# At 159 epoch, Training Loss: 0.7130083441734314
# At 159 epoch, Validation Loss: 0.7080321311950684
# Minimum validation loss detected, saving model......................................................................................
# At 160 epoch, Training Loss: 0.7122955918312073
# At 160 epoch, Validation Loss: 0.7080180048942566
# Minimum validation loss detected, saving model......................................................................................
# At 161 epoch, Training Loss: 0.7123056650161743
# At 161 epoch, Validation Loss: 0.7080077528953552
# Minimum validation loss detected, saving model......................................................................................
# At 162 epoch, Training Loss: 0.7144701480865479
# At 162 epoch, Validation Loss: 0.7080007195472717
# Minimum validation loss detected, saving model......................................................................................
# At 163 epoch, Training Loss: 0.714627206325531
# At 163 epoch, Validation Loss: 0.7079896926879883
# Minimum validation loss detected, saving model......................................................................................
# At 164 epoch, Training Loss: 0.7140998244285583
# At 164 epoch, Validation Loss: 0.7079824209213257
# Minimum validation loss detected, saving model......................................................................................
# At 165 epoch, Training Loss: 0.7124104499816895
# At 165 epoch, Validation Loss: 0.7079725861549377
# Minimum validation loss detected, saving model......................................................................................
# At 166 epoch, Training Loss: 0.7138513326644897
# At 166 epoch, Validation Loss: 0.7079609036445618
# Minimum validation loss detected, saving model......................................................................................
# At 167 epoch, Training Loss: 0.7124324440956116
# At 167 epoch, Validation Loss: 0.7079479098320007
# Minimum validation loss detected, saving model......................................................................................
# At 168 epoch, Training Loss: 0.712765097618103
# At 168 epoch, Validation Loss: 0.7079364061355591
# Minimum validation loss detected, saving model......................................................................................
# At 169 epoch, Training Loss: 0.7118384838104248
# At 169 epoch, Validation Loss: 0.707931399345398
# Minimum validation loss detected, saving model......................................................................................
# At 170 epoch, Training Loss: 0.7131184339523315
# At 170 epoch, Validation Loss: 0.7079233527183533
# Minimum validation loss detected, saving model......................................................................................
# At 171 epoch, Training Loss: 0.7125219106674194
# At 171 epoch, Validation Loss: 0.7079162001609802
# Minimum validation loss detected, saving model......................................................................................
# At 172 epoch, Training Loss: 0.7119987607002258
# At 172 epoch, Validation Loss: 0.7079134583473206
# Minimum validation loss detected, saving model......................................................................................
# At 173 epoch, Training Loss: 0.7148599624633789
# At 173 epoch, Validation Loss: 0.7079079747200012
# Minimum validation loss detected, saving model......................................................................................
# At 174 epoch, Training Loss: 0.7162794470787048
# At 174 epoch, Validation Loss: 0.7079031467437744
# Minimum validation loss detected, saving model......................................................................................
# At 175 epoch, Training Loss: 0.7127247452735901
# At 175 epoch, Validation Loss: 0.7079005837440491
# Minimum validation loss detected, saving model......................................................................................
# At 176 epoch, Training Loss: 0.7135186791419983
# At 176 epoch, Validation Loss: 0.7078967690467834
# Minimum validation loss detected, saving model......................................................................................
# At 177 epoch, Training Loss: 0.7140657901763916
# At 177 epoch, Validation Loss: 0.7078879475593567
# Minimum validation loss detected, saving model......................................................................................
# At 178 epoch, Training Loss: 0.7127358317375183
# At 178 epoch, Validation Loss: 0.7078821659088135
# Minimum validation loss detected, saving model......................................................................................
# At 179 epoch, Training Loss: 0.7141873836517334
# At 179 epoch, Validation Loss: 0.7078805565834045
# Minimum validation loss detected, saving model......................................................................................
# At 180 epoch, Training Loss: 0.7148540616035461
# At 180 epoch, Validation Loss: 0.7078720331192017
# Minimum validation loss detected, saving model......................................................................................
# At 181 epoch, Training Loss: 0.712857186794281
# At 181 epoch, Validation Loss: 0.7078624367713928
# Minimum validation loss detected, saving model......................................................................................
# At 182 epoch, Training Loss: 0.717097282409668
# At 182 epoch, Validation Loss: 0.70786052942276
# Minimum validation loss detected, saving model......................................................................................
# At 183 epoch, Training Loss: 0.7116624712944031
# At 183 epoch, Validation Loss: 0.7078559994697571
# Minimum validation loss detected, saving model......................................................................................
# At 184 epoch, Training Loss: 0.7123064994812012
# At 184 epoch, Validation Loss: 0.7078531980514526
# Minimum validation loss detected, saving model......................................................................................
# At 185 epoch, Training Loss: 0.7165338397026062
# At 185 epoch, Validation Loss: 0.707847535610199
# Minimum validation loss detected, saving model......................................................................................
# At 186 epoch, Training Loss: 0.7110949754714966
# At 186 epoch, Validation Loss: 0.7078361511230469
# Minimum validation loss detected, saving model......................................................................................
# At 187 epoch, Training Loss: 0.7131327390670776
# At 187 epoch, Validation Loss: 0.7078254818916321
# Minimum validation loss detected, saving model......................................................................................
# At 188 epoch, Training Loss: 0.712373673915863
# At 188 epoch, Validation Loss: 0.7078184485435486
# Minimum validation loss detected, saving model......................................................................................
# At 189 epoch, Training Loss: 0.7124235033988953
# At 189 epoch, Validation Loss: 0.7078123092651367
# Minimum validation loss detected, saving model......................................................................................
# At 190 epoch, Training Loss: 0.712177574634552
# At 190 epoch, Validation Loss: 0.7078041434288025
# Minimum validation loss detected, saving model......................................................................................
# At 191 epoch, Training Loss: 0.7127071022987366
# At 191 epoch, Validation Loss: 0.7077938318252563
# Minimum validation loss detected, saving model......................................................................................
# At 192 epoch, Training Loss: 0.711927592754364
# At 192 epoch, Validation Loss: 0.707781970500946
# Minimum validation loss detected, saving model......................................................................................
# At 193 epoch, Training Loss: 0.7135762572288513
# At 193 epoch, Validation Loss: 0.7077711820602417
# Minimum validation loss detected, saving model......................................................................................
# At 194 epoch, Training Loss: 0.7128890156745911
# At 194 epoch, Validation Loss: 0.7077651023864746
# Minimum validation loss detected, saving model......................................................................................
# At 195 epoch, Training Loss: 0.7146652340888977
# At 195 epoch, Validation Loss: 0.7077605128288269
# Minimum validation loss detected, saving model......................................................................................
# At 196 epoch, Training Loss: 0.7143830060958862
# At 196 epoch, Validation Loss: 0.7077589631080627
# Minimum validation loss detected, saving model......................................................................................
# At 197 epoch, Training Loss: 0.7141857147216797
# At 197 epoch, Validation Loss: 0.7077558040618896
# Minimum validation loss detected, saving model......................................................................................
# At 198 epoch, Training Loss: 0.7141569256782532
# At 198 epoch, Validation Loss: 0.7077504992485046
# Minimum validation loss detected, saving model......................................................................................
# At 199 epoch, Training Loss: 0.7110273838043213
# At 199 epoch, Validation Loss: 0.7077469229698181
# Minimum validation loss detected, saving model......................................................................................
# At 200 epoch, Training Loss: 0.7147471904754639
# At 200 epoch, Validation Loss: 0.7077409029006958
# Minimum validation loss detected, saving model......................................................................................
# At 201 epoch, Training Loss: 0.7126363515853882
# At 201 epoch, Validation Loss: 0.7077412009239197
# At 202 epoch, Training Loss: 0.7121708989143372
# At 202 epoch, Validation Loss: 0.7077403664588928
# Minimum validation loss detected, saving model......................................................................................
# At 203 epoch, Training Loss: 0.7126423120498657
# At 203 epoch, Validation Loss: 0.7077334523200989
# Minimum validation loss detected, saving model......................................................................................
# At 204 epoch, Training Loss: 0.7121291160583496
# At 204 epoch, Validation Loss: 0.7077292203903198
# Minimum validation loss detected, saving model......................................................................................
# At 205 epoch, Training Loss: 0.7113773822784424
# At 205 epoch, Validation Loss: 0.7077199816703796
# Minimum validation loss detected, saving model......................................................................................
# At 206 epoch, Training Loss: 0.712537944316864
# At 206 epoch, Validation Loss: 0.7077142000198364
# Minimum validation loss detected, saving model......................................................................................
# At 207 epoch, Training Loss: 0.714417040348053
# At 207 epoch, Validation Loss: 0.7077100276947021
# Minimum validation loss detected, saving model......................................................................................
# At 208 epoch, Training Loss: 0.7135728001594543
# At 208 epoch, Validation Loss: 0.707703709602356
# ...
# Minimum validation loss detected, saving model......................................................................................
# At 467 epoch, Training Loss: 0.7107064127922058
# At 467 epoch, Validation Loss: 0.7059279680252075
# Minimum validation loss detected, saving model......................................................................................
# At 468 epoch, Training Loss: 0.7099093794822693
# At 468 epoch, Validation Loss: 0.7059240937232971
# Minimum validation loss detected, saving model......................................................................................
# At 469 epoch, Training Loss: 0.7124056220054626
# At 469 epoch, Validation Loss: 0.7059198021888733
# Minimum validation loss detected, saving model......................................................................................
# At 470 epoch, Training Loss: 0.7105825543403625
# At 470 epoch, Validation Loss: 0.7059190273284912
# Minimum validation loss detected, saving model......................................................................................
# At 471 epoch, Training Loss: 0.7105163931846619
# At 471 epoch, Validation Loss: 0.7059211730957031
# At 472 epoch, Training Loss: 0.7111103534698486
# At 472 epoch, Validation Loss: 0.705920934677124
# At 473 epoch, Training Loss: 0.7105152010917664
# At 473 epoch, Validation Loss: 0.7059203386306763
# At 474 epoch, Training Loss: 0.7100476026535034
# At 474 epoch, Validation Loss: 0.7059148550033569
# Minimum validation loss detected, saving model......................................................................................
# At 475 epoch, Training Loss: 0.7122187614440918
# At 475 epoch, Validation Loss: 0.7059147953987122
# Minimum validation loss detected, saving model......................................................................................
# At 476 epoch, Training Loss: 0.7124790549278259
# At 476 epoch, Validation Loss: 0.7059120535850525
# Minimum validation loss detected, saving model......................................................................................
# At 477 epoch, Training Loss: 0.7114972472190857
# At 477 epoch, Validation Loss: 0.705912172794342
# At 478 epoch, Training Loss: 0.7101500630378723
# At 478 epoch, Validation Loss: 0.7059140205383301
# At 479 epoch, Training Loss: 0.7091631889343262
# At 479 epoch, Validation Loss: 0.705908477306366
# Minimum validation loss detected, saving model......................................................................................
# At 480 epoch, Training Loss: 0.7119637131690979
# At 480 epoch, Validation Loss: 0.7059025764465332
# Minimum validation loss detected, saving model......................................................................................
# At 481 epoch, Training Loss: 0.7092800736427307
# At 481 epoch, Validation Loss: 0.7059022784233093
# Minimum validation loss detected, saving model......................................................................................
# At 482 epoch, Training Loss: 0.7117359042167664
# At 482 epoch, Validation Loss: 0.7058990597724915
# Minimum validation loss detected, saving model......................................................................................
# At 483 epoch, Training Loss: 0.7120643258094788
# At 483 epoch, Validation Loss: 0.7058942317962646
# Minimum validation loss detected, saving model......................................................................................
# At 484 epoch, Training Loss: 0.7125246524810791
# At 484 epoch, Validation Loss: 0.7058853507041931
# Minimum validation loss detected, saving model......................................................................................
# At 485 epoch, Training Loss: 0.713975727558136
# At 485 epoch, Validation Loss: 0.7058799266815186
# Minimum validation loss detected, saving model......................................................................................
# At 486 epoch, Training Loss: 0.708782434463501
# At 486 epoch, Validation Loss: 0.7058728933334351
# Minimum validation loss detected, saving model......................................................................................
# At 487 epoch, Training Loss: 0.7124665379524231
# At 487 epoch, Validation Loss: 0.7058658003807068
# Minimum validation loss detected, saving model......................................................................................
# At 488 epoch, Training Loss: 0.7091048359870911
# At 488 epoch, Validation Loss: 0.7058582305908203
# Minimum validation loss detected, saving model......................................................................................
# At 489 epoch, Training Loss: 0.708524763584137
# At 489 epoch, Validation Loss: 0.7058480381965637
# Minimum validation loss detected, saving model......................................................................................
# At 490 epoch, Training Loss: 0.7091501355171204
# At 490 epoch, Validation Loss: 0.705839991569519
# Minimum validation loss detected, saving model......................................................................................
# At 491 epoch, Training Loss: 0.7114999890327454
# At 491 epoch, Validation Loss: 0.7058385014533997
# Minimum validation loss detected, saving model......................................................................................
# At 492 epoch, Training Loss: 0.7091216444969177
# At 492 epoch, Validation Loss: 0.7058312892913818
# Minimum validation loss detected, saving model......................................................................................
# At 493 epoch, Training Loss: 0.7112524509429932
# At 493 epoch, Validation Loss: 0.7058292031288147
# Minimum validation loss detected, saving model......................................................................................
# At 494 epoch, Training Loss: 0.7117249965667725
# At 494 epoch, Validation Loss: 0.7058213353157043
# Minimum validation loss detected, saving model......................................................................................
# At 495 epoch, Training Loss: 0.7086235880851746
# At 495 epoch, Validation Loss: 0.7058151364326477
# Minimum validation loss detected, saving model......................................................................................
# At 496 epoch, Training Loss: 0.7099304795265198
# At 496 epoch, Validation Loss: 0.7058095932006836
# Minimum validation loss detected, saving model......................................................................................
# At 497 epoch, Training Loss: 0.7132518887519836
# At 497 epoch, Validation Loss: 0.7058064341545105
# Minimum validation loss detected, saving model......................................................................................
# At 498 epoch, Training Loss: 0.7114157676696777
# At 498 epoch, Validation Loss: 0.70579993724823
# Minimum validation loss detected, saving model......................................................................................
# At 499 epoch, Training Loss: 0.7078583836555481
# At 499 epoch, Validation Loss: 0.7057923674583435
# Minimum validation loss detected, saving model......................................................................................
# At 500 epoch, Training Loss: 0.709762692451477
# At 500 epoch, Validation Loss: 0.7057859301567078
# Minimum validation loss detected, saving model......................................................................................
# At 501 epoch, Training Loss: 0.7085210084915161
# At 501 epoch, Validation Loss: 0.7057733535766602
# Minimum validation loss detected, saving model......................................................................................
# At 502 epoch, Training Loss: 0.7116582989692688
# At 502 epoch, Validation Loss: 0.7057645320892334
# Minimum validation loss detected, saving model......................................................................................
# At 503 epoch, Training Loss: 0.7129536271095276
# At 503 epoch, Validation Loss: 0.7057585716247559
# Minimum validation loss detected, saving model......................................................................................
# At 504 epoch, Training Loss: 0.7086066007614136
# At 504 epoch, Validation Loss: 0.7057507634162903
# Minimum validation loss detected, saving model......................................................................................
# At 505 epoch, Training Loss: 0.7112900614738464
# At 505 epoch, Validation Loss: 0.7057438492774963
# Minimum validation loss detected, saving model......................................................................................
# At 506 epoch, Training Loss: 0.7097620964050293
# At 506 epoch, Validation Loss: 0.7057344913482666
# Minimum validation loss detected, saving model......................................................................................
# At 507 epoch, Training Loss: 0.7106661200523376
# At 507 epoch, Validation Loss: 0.7057250738143921
# Minimum validation loss detected, saving model......................................................................................
# At 508 epoch, Training Loss: 0.7117940187454224
# At 508 epoch, Validation Loss: 0.7057226300239563
# Minimum validation loss detected, saving model......................................................................................
# At 509 epoch, Training Loss: 0.7111587524414062
# At 509 epoch, Validation Loss: 0.7057156562805176
# Minimum validation loss detected, saving model......................................................................................
# At 510 epoch, Training Loss: 0.7091147899627686
# At 510 epoch, Validation Loss: 0.7057155966758728
# Minimum validation loss detected, saving model......................................................................................
# At 511 epoch, Training Loss: 0.7125344276428223
# At 511 epoch, Validation Loss: 0.7057141661643982
# Minimum validation loss detected, saving model......................................................................................
# At 512 epoch, Training Loss: 0.7098562717437744
# At 512 epoch, Validation Loss: 0.7057153582572937
# At 513 epoch, Training Loss: 0.7095509767532349
# At 513 epoch, Validation Loss: 0.7057157158851624
# At 514 epoch, Training Loss: 0.7093765139579773
# At 514 epoch, Validation Loss: 0.7057105302810669
# Minimum validation loss detected, saving model......................................................................................
# At 515 epoch, Training Loss: 0.7119280099868774
# At 515 epoch, Validation Loss: 0.7057062387466431
# Minimum validation loss detected, saving model......................................................................................
# At 516 epoch, Training Loss: 0.7098385095596313
# At 516 epoch, Validation Loss: 0.7057031989097595
# Minimum validation loss detected, saving model......................................................................................
# At 517 epoch, Training Loss: 0.7109097838401794
# At 517 epoch, Validation Loss: 0.7056970000267029
# Minimum validation loss detected, saving model......................................................................................
# At 518 epoch, Training Loss: 0.708925187587738
# At 518 epoch, Validation Loss: 0.7056933641433716
# Minimum validation loss detected, saving model......................................................................................
# At 519 epoch, Training Loss: 0.709588885307312
# At 519 epoch, Validation Loss: 0.7056868076324463
# Minimum validation loss detected, saving model......................................................................................
# At 520 epoch, Training Loss: 0.7098940014839172
# At 520 epoch, Validation Loss: 0.7056837677955627
# Minimum validation loss detected, saving model......................................................................................
# At 521 epoch, Training Loss: 0.7137858271598816
# At 521 epoch, Validation Loss: 0.7056782841682434
# Minimum validation loss detected, saving model......................................................................................
# At 522 epoch, Training Loss: 0.7101709246635437
# At 522 epoch, Validation Loss: 0.7056751251220703
# Minimum validation loss detected, saving model......................................................................................
# At 523 epoch, Training Loss: 0.7095779776573181
# At 523 epoch, Validation Loss: 0.7056681513786316
# Minimum validation loss detected, saving model......................................................................................
# At 524 epoch, Training Loss: 0.7094762921333313
# At 524 epoch, Validation Loss: 0.7056668400764465
# Minimum validation loss detected, saving model......................................................................................
# At 525 epoch, Training Loss: 0.7089735865592957
# At 525 epoch, Validation Loss: 0.7056584358215332
# Minimum validation loss detected, saving model......................................................................................
# At 526 epoch, Training Loss: 0.7092715501785278
# At 526 epoch, Validation Loss: 0.7056472301483154
# Minimum validation loss detected, saving model......................................................................................
# At 527 epoch, Training Loss: 0.7095347046852112
# At 527 epoch, Validation Loss: 0.7056365609169006
# Minimum validation loss detected, saving model......................................................................................
# At 528 epoch, Training Loss: 0.7096187472343445
# At 528 epoch, Validation Loss: 0.7056269645690918
# Minimum validation loss detected, saving model......................................................................................
# At 529 epoch, Training Loss: 0.7118575572967529
# At 529 epoch, Validation Loss: 0.7056174874305725
# Minimum validation loss detected, saving model......................................................................................
# At 530 epoch, Training Loss: 0.7117880582809448
# At 530 epoch, Validation Loss: 0.7056107521057129
# Minimum validation loss detected, saving model......................................................................................
# At 531 epoch, Training Loss: 0.7109123468399048
# At 531 epoch, Validation Loss: 0.7055973410606384
# Minimum validation loss detected, saving model......................................................................................
# At 532 epoch, Training Loss: 0.7102422118186951
# At 532 epoch, Validation Loss: 0.7055954337120056
# Minimum validation loss detected, saving model......................................................................................
# At 533 epoch, Training Loss: 0.7101929783821106
# At 533 epoch, Validation Loss: 0.7055882811546326
# Minimum validation loss detected, saving model......................................................................................
# At 534 epoch, Training Loss: 0.7105859518051147
# At 534 epoch, Validation Loss: 0.7055833339691162
# Minimum validation loss detected, saving model......................................................................................
# At 535 epoch, Training Loss: 0.7105600237846375
# At 535 epoch, Validation Loss: 0.7055795788764954
# Minimum validation loss detected, saving model......................................................................................
# At 536 epoch, Training Loss: 0.7109079360961914
# At 536 epoch, Validation Loss: 0.7055747509002686
# Minimum validation loss detected, saving model......................................................................................
# At 537 epoch, Training Loss: 0.7122411131858826
# At 537 epoch, Validation Loss: 0.7055685520172119
# Minimum validation loss detected, saving model......................................................................................
# At 538 epoch, Training Loss: 0.7114250063896179
# At 538 epoch, Validation Loss: 0.7055647969245911
# Minimum validation loss detected, saving model......................................................................................

# %%
torch.load("ccFraud.pt")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x_epochs=np.linspace(1,n_epoch,n_epoch).astype(dtype=int)
plt.plot(x_epochs,train_loss)
plt.plot(x_epochs,valid_loss)
plt.xlabel("N Epochs")
plt.ylabel("Loss")
plt.grid()
plt.legend(["Training","Validation"])
plt.show()

# %%
k=np.linspace(0,1,10)
TPR=[]
FPR=[]
for n in k:
    outputs=[]
    targets=[]
    for data,target in test_loader:
        output=model(data.float())
        output=torch.sigmoid(output.cpu())
        output=list(np.where(output<n,0,1)[:])
        target=list(target.cpu().numpy())
        outputs+=output
        targets+=target

    outputs_of_model=np.stack(outputs,axis=0).squeeze().astype(dtype=int)
    targets_of_model=np.array(targets).astype(dtype=int)
    
    #detect True Negatives, False Positives, False Negatives, True Positives
    TN=np.array(targets_of_model[outputs_of_model==0]==0).sum()
    FP=np.array(targets_of_model[outputs_of_model==1]==0).sum()
    FN=np.array(targets_of_model[outputs_of_model==0]==1).sum()
    TP=np.array(targets_of_model[outputs_of_model==1]==1).sum()

    TPR.append(TP/(TP+FN))
    FPR.append(FP/(FP+TN))
    
#Plot True Positive Rate and False Positive Rate
plt.plot(FPR,TPR)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

AUC=0.0;
for i in range(len(TPR)-1):
    AUC+=np.abs((TPR[i]+TPR[i+1])*(FPR[i+1]-FPR[i])/2)
  
  
print("Estimated AUC: {}".format(AUC))

# %%
outputs=[]
targets=[]
for data,target in test_loader:
    output=model(data.float())
    output=torch.sigmoid(output.cpu())
    output=list(np.where(output<0.5,0,1)[:])
    target=list(target.cpu().numpy())
    outputs+=output
    targets+=target

outputs_of_model=np.stack(outputs,axis=0).squeeze().astype(dtype=int)
targets_of_model=np.array(targets).astype(dtype=int)


TN=np.array(targets_of_model[outputs_of_model==0]==0).sum()
FP=np.array(targets_of_model[outputs_of_model==1]==0).sum()
FN=np.array(targets_of_model[outputs_of_model==0]==1).sum()
TP=np.array(targets_of_model[outputs_of_model==1]==1).sum()


print("True Positives: {}".format(TP))
print("True Negatives: {}".format(TN))
print("False Positives: {}".format(FP))
print("False Negatives: {}".format(FN))


precision=TP/(TP+FP)
recall=TP/(TP+FN)
print("Model Precision: {}".format(precision))
print("Model Recall: {}".format(recall))

F1=2*precision*recall/(precision+recall)

print("F1-score: {}".format(F1))

# %%
(TP+TN)/(TP+FP+TN+FN)
